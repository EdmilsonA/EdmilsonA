# %% [markdown]
# <a href="https://colab.research.google.com/github/EdmilsonA/EdmilsonA/blob/main/aula01.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Obter as duas notas de provas
nota1 = float(input("Digite a primeira nota: "))
nota2 = float(input("Digite a segunda nota: "))
#Calcular a média aritmética
media = (nota1 + nota2)/2
#Se a média for igual ou maior que 7, o aluno foi aprovado
if media >= 7:
    print("Aprovado")
#Se não, ele foi reprovado
else:
    print("Reprovado")
# Out:
# Digite a primeira nota: 7
# Digite a segunda nota: 8
# Aprovado
