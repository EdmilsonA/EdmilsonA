# %% [markdown]
# <a href="https://colab.research.google.com/github/EdmilsonA/EdmilsonA/blob/main/aula01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nota1 = float(input("Digite a primeira nota: "))
nota2 = float(input("Digite a segunda nota: "))

media = (nota1 + nota2)/2

if media >= 7:
    print("Aprovado")

else:
    print("Reprovado")
# Out:
# Digite a primeira nota: 7
# Digite a segunda nota: 8
# Aprovado
